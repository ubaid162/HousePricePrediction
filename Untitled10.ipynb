# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"D:\DataScience\dataSet\Bengaluru_House_Data.csv")
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
data.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %% [markdown]
# ### Removing unnecessary columns

# %%
data.drop(['balcony','society','availability'],axis = 1,inplace = True)
data
# Out:
#                   area_type                  location       size total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK       1056
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom       2600
# 2            Built-up  Area               Uttarahalli      3 BHK       1440
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK       1521
# 4      Super built-up  Area                  Kothanur      2 BHK       1200
# ...                     ...                       ...        ...        ...
# 13315        Built-up  Area                Whitefield  5 Bedroom       3453
# 13316  Super built-up  Area             Richards Town      4 BHK       3600
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK       1141
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK       4689
# 13319  Super built-up  Area              Doddathoguru      1 BHK        550
#
#        bath   price
# 0       2.0   39.07
# ...

# %% [markdown]
# ### Removing Duplicates

# %%
data.duplicated().sum()
# Out:
# 811

# %%
data.drop_duplicates()
# Out:
#                   area_type                  location       size total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK       1056
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom       2600
# 2            Built-up  Area               Uttarahalli      3 BHK       1440
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK       1521
# 4      Super built-up  Area                  Kothanur      2 BHK       1200
# ...                     ...                       ...        ...        ...
# 13314  Super built-up  Area         Green Glen Layout      3 BHK       1715
# 13315        Built-up  Area                Whitefield  5 Bedroom       3453
# 13316  Super built-up  Area             Richards Town      4 BHK       3600
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK       1141
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK       4689
#
#        bath   price
# 0       2.0   39.07
# ...

# %% [markdown]
# ### Handling missing values

# %%
data.isna().sum()
# Out:
# area_type      0
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
data['bath'] = data['bath'].fillna(method = 'ffill')
# Out:
# C:\Users\UBAID\AppData\Local\Temp\ipykernel_18472\3933686989.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['bath'] = data['bath'].fillna(method = 'ffill')

# %%
data['location'].fillna(data['location'].mode()[0],inplace =True)
# Out:
# C:\Users\UBAID\AppData\Local\Temp\ipykernel_18472\3348810235.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['location'].fillna(data['location'].mode()[0],inplace =True)

# %%
data['size'].fillna(data['size'].mode()[0],inplace = True)
# Out:
# C:\Users\UBAID\AppData\Local\Temp\ipykernel_18472\2565228764.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['size'].fillna(data['size'].mode()[0],inplace = True)

# %%
data['bhk'] = data['size'].str.extract('(\d+)').astype('int')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\UBAID\AppData\Local\Temp\ipykernel_18472\2368805755.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data['bhk'] = data['size'].str.extract('(\d+)').astype('int')

# %%
data
# Out:
#                   area_type                  location       size total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK       1056
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom       2600
# 2            Built-up  Area               Uttarahalli      3 BHK       1440
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK       1521
# 4      Super built-up  Area                  Kothanur      2 BHK       1200
# ...                     ...                       ...        ...        ...
# 13315        Built-up  Area                Whitefield  5 Bedroom       3453
# 13316  Super built-up  Area             Richards Town      4 BHK       3600
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK       1141
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK       4689
# 13319  Super built-up  Area              Doddathoguru      1 BHK        550
#
#        bath   price  bhk
# 0       2.0   39.07    2
# ...

# %%
data.drop('size',axis =1,inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   13320 non-null  object
#  1   location    13320 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13320 non-null  float64
#  4   price       13320 non-null  float64
#  5   bhk         13320 non-null  int32
# dtypes: float64(2), int32(1), object(3)
# memory usage: 572.5+ KB

# %%
def convert_to_float(val):
    if isinstance(val,str) and '-' in val:
        start,end = val.split('-')
        return (float(start) +float(end))/2
    try:
        return float(val)
    except:
        return None

data['total_sqft'] = data['total_sqft'].apply(convert_to_float)

# %%
data.dropna(inplace = True)

# %%
#Addding Extra column
data['price_per_sqft'] = data['price']*100000/data['total_sqft']

# %% [markdown]
# ### Feature Encoding

# %%
# Removing less no of location to reduce noice
loc_count = data['location'].value_counts()
loc_less_than_10 = loc_count[loc_count <= 10].index
data['location'] = data['location'].apply(lambda x : 'other' if x in loc_less_than_10 else x)

# %%
# Rempve where sqrt of bhk too small unlealistic
data = data[data['total_sqft']/data['bhk'] >= 300]

# %%
# Removing rows where bathrooms are more than bedroom xx
data = data[data['bath'] <= data['bhk']+2]

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories = [['Carpet  Area','Built-up  Area','Super built-up  Area', 'Plot  Area']] )
area = oe.fit_transform(data[['area_type']])
data['area'] = area.astype('int')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['location'] = le.fit_transform(data['location'])

# %%
data.drop('area_type',axis = 1,inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12518 entries, 0 to 13319
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location        12518 non-null  int32
#  1   total_sqft      12518 non-null  float64
#  2   bath            12518 non-null  float64
#  3   price           12518 non-null  float64
#  4   bhk             12518 non-null  int32
#  5   price_per_sqft  12518 non-null  float64
#  6   area            12518 non-null  int32
# dtypes: float64(4), int32(3)
# memory usage: 635.7 KB

# %% [markdown]
# ### Data Visualization

# %%
sns.scatterplot(x = 'total_sqft',y = 'price',data=data,hue = data['bhk'].astype('str'),palette = 'cool')
plt.title('Totla sqft vs price (colored by bhk')
plt.show()

# %%
sns.lineplot(x = 'bhk',y= 'price',data =data,palette = 'Accent')
plt.title('Price distribution across BHK')
plt.show()
# Out:
# C:\Users\UBAID\AppData\Local\Temp\ipykernel_18472\620919485.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x = 'bhk',y= 'price',data =data,palette = 'Accent')

# %%
corr = data.corr()

# %%
sns.heatmap(corr,annot = True)
plt.title('Heatmap')
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
x = data[['area','price_per_sqft', 'location', 'total_sqft', 'bath', 'bhk']]
y= data[['price']]

# %% [markdown]
# ### Split Data into train and test

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %% [markdown]
# ### modelling

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
lr_r2 = r2_score(y_test,y_pred)
print(lr_r2)
# Out:
# 0.5731210729530996

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train, y_train)
# Out:
# C:\Users\UBAID\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
Ry_pred = rf.predict(x_test)
rf_r2 = r2_score(y_test,y_pred)
print(rf_r2)
# Out:
# 0.5731210729530996

# %%
plt.scatter(y_test,Ry_pred,alpha = 0.5)
plt.show()

# %% [markdown]
# ### Predict the price

# %%
n = {
    'area':float(input('Area type: ')),
    'price_per_sqft':float(input('Enter the price per sqft: ')),
    'location':float(input('Enter the location : ')),
    'total_sqft':float(input('Total Sqft :')),
    'bath':float(input('Enter the number of bathrooms :')),
    'bhk':float(input("Enter the bhk :"))
}
new = pd.DataFrame([n])
print("\n",new)
print("\n**************************PREDICTION***************************")
predict = rf.predict(new)
print("\n\nThe prediction price is: ",predict*10000)
# Out:
# Area type:  3
# Enter the price per sqft:  6000
# Enter the location :  200
# Total Sqft : 1056
# Enter the number of bathrooms : 2
# Enter the bhk : 2
#     area  price_per_sqft  location  total_sqft  bath  bhk
# 0   3.0          6000.0     200.0      1056.0   2.0  2.0
#
# **************************PREDICTION***************************
#
#
# The prediction price is:  [632789.]
